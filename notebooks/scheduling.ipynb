# %% [markdown]
# ### Use case description for the CCB cadence python package ###

# %%
import os
import glob
import numpy as np
import pandas as pd
from pathlib import Path
import time
import timeboard as tb
import timeboard.calendars.US as US
import datetime
import holidays
from faker import Faker

# Appearance of the Notebook
from IPython.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))

# Import the package
# %load_ext autoreload
# %autoreload 2
import cadence
from cadence.mscheduler import Meetings
print(f'Package version: {cadence.__version__}')
# Out:
# <style>.container { width:100% !important; }</style>
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Package version: 0.0.post1.dev5+g0626a2e

# %% [markdown]
# ### Meeting participants and settings ###

# %%
# Create a list of random names
n_participants = 9

# Random seed
seed = 123

# Create fake data
fake = Faker()
Faker.seed(seed)
name_list = [fake.name() for name in range(n_participants)]
print(name_list)

# Day of the week we want to have a meeting
meeting_day_str = 'Wednesday'

# This translates to a number that the timeboard package needs
days_str = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
days_dict = dict(zip(days_str, range(len(days_str))))
display(days_dict)
# Out:
# ['Brandon Russell', 'Steven Johnson', 'Evelyn Christian', 'George Cook', 'Aaron Graham', 'Kyle Jones', 'Jerome Whitehead', 'Charles Tyler', 'Thomas Berry']
# {'Monday': 0,
#  'Tuesday': 1,
#  'Wednesday': 2,
#  'Thursday': 3,
#  'Friday': 4,
#  'Saturday': 5,
#  'Sunday': 6}

# %%
# Create a data frame with the names
name_df = pd.DataFrame({'full_name': name_list})
name_df[['name', 'last_name']] = name_df['full_name'].str.split(' ', expand=True)
display(name_df)
# Out:
#           full_name     name  last_name
# 0   Brandon Russell  Brandon    Russell
# 1    Steven Johnson   Steven    Johnson
# 2  Evelyn Christian   Evelyn  Christian
# 3       George Cook   George       Cook
# 4      Aaron Graham    Aaron     Graham
# 5        Kyle Jones     Kyle      Jones
# 6  Jerome Whitehead   Jerome  Whitehead
# 7     Charles Tyler  Charles      Tyler
# 8      Thomas Berry   Thomas      Berry

# %% [markdown]
# ### Create a sequence of presenters ###

# %%
# Get the list of presenters from the data frame in alphabetical order
name_col = 'name'
presenters = sorted(list(name_df[name_col].unique()))
print(presenters)
# Out:
# ['Aaron', 'Brandon', 'Charles', 'Evelyn', 'George', 'Jerome', 'Kyle', 'Steven', 'Thomas']

# %%
# If we are not happy with this sequence, we can rotate it
# Or, just change it manually
from cadence.mscheduler import cyclic_permutate
old_presenters = presenters.copy()
# Rotate the list, let's say to start with one particular name
new_presenters = cyclic_permutate(lst_in=old_presenters, name='Evelyn')
print(old_presenters)
print(new_presenters)
# Out:
# ['Aaron', 'Brandon', 'Charles', 'Evelyn', 'George', 'Jerome', 'Kyle', 'Steven', 'Thomas']
# ['Evelyn', 'George', 'Jerome', 'Kyle', 'Steven', 'Thomas', 'Aaron', 'Brandon', 'Charles']

# %% [markdown]
# ### Create a sequence of weekly meetings ###

# %%
# Lets do some cleanup of the spreadsheet
# small letters for the column names
tm = tm_raw.copy()
tm.columns = [col.lower() for col in tm.columns]

# small letters for emails and group, first letter capitalize for names
tm[email_col] = tm[email_col].str.lower()
tm[group_col] = tm[group_col].str.lower()
tm[name_col] = tm[name_col].str.title()

# Sort by group and then name
tm = tm.sort_values(by=['group', 'name'], ascending=True).reset_index(drop=True)

# save the name ist as a csv_file
presenter_list_file_name = f'{os.path.splitext(group_members_file_name)[0]}_list.csv'
presenter_list_file = os.path.join(data_dir, presenter_list_file_name)
tm.to_csv(presenter_list_file, index=False)
display(tm)
# Out:
#        name                                         email     group
# 0   Andreas               andreas_werdich@hms.harvard.edu   ai-data
# 1    Gerald               gerald_kiwanuka@hms.harvard.edu   ai-data
# 2    Nathan                 nathan_palmer@hms.harvard.edu   ai-data
# 3       Sam              samantha_pullman@hms.harvard.edu   ai-data
# 4     Sreya                sreya_banerjee@hms.harvard.edu   ai-data
# 5    Andrew                  andrew_ghazi@hms.harvard.edu  comp-bio
# 6   Anthony  anthony-alexander_christidis@hms.harvard.edu  comp-bio
# 7      Grey                   grey_kuling@hms.harvard.edu  comp-bio
# 8    Ludwig            ludwig_geistlinger@hms.harvard.edu  comp-bio
# 9      Tram                   tram_nguyen@hms.harvard.edu  comp-bio
# 10   Tyrone                    tyrone_lee@hms.harvard.edu  comp-bio

# %%
# People who are not presenting
rm_name = ['nathan', 'ludwig']
rm_name = [nm.title() for nm in rm_name]

# Remove the names that we do not want in the schedule
presenters_df = tm.loc[~tm.get(name_col).isin(rm_name)]

# %%
# Merge two lists alternatively. 
# Start with shuffling everyone
presenters_df = presenters_df.sample(frac=1, random_state=123)
# And this method does not care if the lists do not have the same length.
group_list = presenters_df.get('group').unique()
name_lists = [sorted(list(presenters_df.loc[presenters_df.get(group_col) == grp, name_col].values)) \
           for grp in group_list]
presenters = merge_alternatively(name_lists[0], name_lists[1])
print(presenters)
# Out:
# ['Andrew', 'Andreas', 'Anthony', 'Gerald', 'Grey', 'Sam', 'Tram', 'Sreya', 'Tyrone']

# %%
# Make the calendar
def create_timeboard(start_date, 
                     end_date, 
                     name_list, 
                     start_name, 
                     meeting_day=2,
                     date_col=date_col,
                     name_col=name_col,
                     comment_col=comment_col):

    # Create a holiday calendar
    us_ma_holidays = holidays.country_holidays('US', subdiv='MA')

    # Rotate the speakers so that the start_name comes first
    nlist = cyclic_permutate(name_list, start_name)
    
    # Define the list of speakers
    team_order = tb.RememberingPattern(nlist)
    
    # Set a weekly marker for every Wednesday
    week_day = tb.Marker(each='W', at=[{'days': meeting_day}])
    weekly = tb.Organizer(marker=week_day, structure=team_order)
    cal = tb.Timeboard(base_unit_freq='D', start=start_date, end=end_date, layout=weekly)
    cal = cal.to_dataframe()
    cal = cal.reset_index(drop=True)[['start', 'label']].\
                    rename(columns={'start': date_col, 'label': name_col})

    # Merge with the other member information
    cal = cal.merge(right=tm, on='name', how='left')
    
    # Add the MA holidays to this data frame
    cal = cal.assign(holiday=cal.get('date').apply(lambda dt: dt in us_ma_holidays),
                     comment=cal.get('date').apply(lambda dt: us_ma_holidays.get(dt)))
    
    return cal

# %%
# Create a new meeting schedule
start_date = ('2024-08-14')
end_date = ('2025-03-24')
cal_df = create_timeboard(start_date=start_date, 
                          end_date=end_date, 
                          name_list=presenters,
                          start_name='andreas')

print(presenters)
display(cal_df)
# Out:
# ['Andrew', 'Andreas', 'Anthony', 'Gerald', 'Grey', 'Sam', 'Tram', 'Sreya', 'Tyrone']
# /home/andreas/gitrepos/pyutils/.venv/lib/python3.10/site-packages/timeboard/when.py:37: FutureWarning: 'S' is deprecated and will be removed in a future version, please use 's' instead.
#   start_times = pi.to_timestamp(how='start', freq='S')
#          date     name                                         email  \
# 0  2024-08-14  Andreas               andreas_werdich@hms.harvard.edu
# 1  2024-08-21  Anthony  anthony-alexander_christidis@hms.harvard.edu
# 2  2024-08-28   Gerald               gerald_kiwanuka@hms.harvard.edu
# 3  2024-09-04     Grey                   grey_kuling@hms.harvard.edu
# 4  2024-09-11      Sam              samantha_pullman@hms.harvard.edu
# 5  2024-09-18     Tram                   tram_nguyen@hms.harvard.edu
# 6  2024-09-25    Sreya                sreya_banerjee@hms.harvard.edu
# 7  2024-10-02   Tyrone                    tyrone_lee@hms.harvard.edu
# 8  2024-10-09   Andrew                  andrew_ghazi@hms.harvard.edu
# 9  2024-10-16  Andreas               andreas_werdich@hms.harvard.edu
# 10 2024-10-23  Anthony  anthony-alexander_christidis@hms.harvard.edu
# 11 2024-10-30   Gerald               gerald_kiwanuka@hms.harvard.edu
# 12 2024-11-06     Grey                   grey_kuling@hms.harvard.edu
# 13 2024-11-13      Sam              samantha_pullman@hms.harvard.edu
# 14 2024-11-20     Tram                   tram_nguyen@hms.harvard.edu
# 15 2024-11-27    Sreya                sreya_banerjee@hms.harvard.edu
# 16 2024-12-04   Tyrone                    tyrone_lee@hms.harvard.edu
# 17 2024-12-11   Andrew                  andrew_ghazi@hms.harvard.edu
# 18 2024-12-18  Andreas               andreas_werdich@hms.harvard.edu
# 19 2024-12-25  Anthony  anthony-alexander_christidis@hms.harvard.edu
# 20 2025-01-01   Gerald               gerald_kiwanuka@hms.harvard.edu
# 21 2025-01-08     Grey                   grey_kuling@hms.harvard.edu
# 22 2025-01-15      Sam              samantha_pullman@hms.harvard.edu
# 23 2025-01-22     Tram                   tram_nguyen@hms.harvard.edu
# 24 2025-01-29    Sreya                sreya_banerjee@hms.harvard.edu
# 25 2025-02-05   Tyrone                    tyrone_lee@hms.harvard.edu
# 26 2025-02-12   Andrew                  andrew_ghazi@hms.harvard.edu
# 27 2025-02-19  Andreas               andreas_werdich@hms.harvard.edu
# 28 2025-02-26  Anthony  anthony-alexander_christidis@hms.harvard.edu
# 29 2025-03-05   Gerald               gerald_kiwanuka@hms.harvard.edu
# 30 2025-03-12     Grey                   grey_kuling@hms.harvard.edu
# 31 2025-03-19      Sam              samantha_pullman@hms.harvard.edu
#
#        group  holiday         comment
# 0    ai-data    False            None
# 1   comp-bio    False            None
# 2    ai-data    False            None
# 3   comp-bio    False            None
# 4    ai-data    False            None
# 5   comp-bio    False            None
# 6    ai-data    False            None
# 7   comp-bio    False            None
# 8   comp-bio    False            None
# 9    ai-data    False            None
# 10  comp-bio    False            None
# 11   ai-data    False            None
# 12  comp-bio    False            None
# 13   ai-data    False            None
# 14  comp-bio    False            None
# 15   ai-data    False            None
# 16  comp-bio    False            None
# 17  comp-bio    False            None
# 18   ai-data    False            None
# 19  comp-bio     True   Christmas Day
# 20   ai-data     True  New Year's Day
# 21  comp-bio    False            None
# 22   ai-data    False            None
# 23  comp-bio    False            None
# 24   ai-data    False            None
# 25  comp-bio    False            None
# 26  comp-bio    False            None
# 27   ai-data    False            None
# 28  comp-bio    False            None
# 29   ai-data    False            None
# 30  comp-bio    False            None
# 31   ai-data    False            None

# %% [markdown]
# ### Function to skip dates ###

# %%
def skip_date(cal_df, skip_date, skip_comment, name_col='name', date_col='date', comment_col='comment'):
    """ Skip dates in timeboard output """
    cdf_skip = cal_df.loc[cal_df.get(date_col)==skip_date]
    cdf_skip.loc[cdf_skip.get(date_col)==skip_date, comment_col] = skip_comment
    if len(cdf_skip)>0:
        cal_df_before = cal_df.loc[cal_df.get(date_col) < skip_date]
        cal_df_after = cal_df.loc[cal_df.get(date_col) > skip_date]
        name_list = list(cal_df.get(name_col).unique())
        # Re-create the calendar for the dates after the skip date
        cal_df_after = create_timeboard(start_date=cal_df_after[date_col].min(), 
                                        end_date=cal_df_after[date_col].max(), 
                                        name_list=name_list,
                                        start_name=cdf_skip.get('name').values[0])
        cal_df = pd.concat([cdf_before, cdf_skip, cdf_after], axis=0, ignore_index=True)
    else:
        raise ValueError(f'Skip date {skip_date} is not in data.')
    return cal_df

# %%
# Test this function
cal_df = skip_date(cal_df=cal_df,
                   skip_date='2024-09-04',
                   skip_comment='No meeting, party time.')

display(cal_df)
# Out:
# /home/andreas/gitrepos/pyutils/.venv/lib/python3.10/site-packages/timeboard/when.py:37: FutureWarning: 'S' is deprecated and will be removed in a future version, please use 's' instead.
#   start_times = pi.to_timestamp(how='start', freq='S')
#          date     name                                         email  \
# 0  2024-08-14  Andreas               andreas_werdich@hms.harvard.edu
# 1  2024-08-21  Anthony  anthony-alexander_christidis@hms.harvard.edu
# 2  2024-08-28   Gerald               gerald_kiwanuka@hms.harvard.edu
# 3  2024-09-04     Grey                   grey_kuling@hms.harvard.edu
# 4  2024-09-11     Grey                   grey_kuling@hms.harvard.edu
# 5  2024-09-18      Sam              samantha_pullman@hms.harvard.edu
# 6  2024-09-25     Tram                   tram_nguyen@hms.harvard.edu
# 7  2024-10-02    Sreya                sreya_banerjee@hms.harvard.edu
# 8  2024-10-09   Tyrone                    tyrone_lee@hms.harvard.edu
# 9  2024-10-16   Andrew                  andrew_ghazi@hms.harvard.edu
# 10 2024-10-23  Andreas               andreas_werdich@hms.harvard.edu
# 11 2024-10-30  Anthony  anthony-alexander_christidis@hms.harvard.edu
# 12 2024-11-06   Gerald               gerald_kiwanuka@hms.harvard.edu
# 13 2024-11-13     Grey                   grey_kuling@hms.harvard.edu
# 14 2024-11-20      Sam              samantha_pullman@hms.harvard.edu
# 15 2024-11-27     Tram                   tram_nguyen@hms.harvard.edu
# 16 2024-12-04    Sreya                sreya_banerjee@hms.harvard.edu
# 17 2024-12-11   Tyrone                    tyrone_lee@hms.harvard.edu
# 18 2024-12-18   Andrew                  andrew_ghazi@hms.harvard.edu
# 19 2024-12-25  Andreas               andreas_werdich@hms.harvard.edu
# 20 2025-01-01  Anthony  anthony-alexander_christidis@hms.harvard.edu
# 21 2025-01-08   Gerald               gerald_kiwanuka@hms.harvard.edu
# 22 2025-01-15     Grey                   grey_kuling@hms.harvard.edu
# 23 2025-01-22      Sam              samantha_pullman@hms.harvard.edu
# 24 2025-01-29     Tram                   tram_nguyen@hms.harvard.edu
# 25 2025-02-05    Sreya                sreya_banerjee@hms.harvard.edu
# 26 2025-02-12   Tyrone                    tyrone_lee@hms.harvard.edu
# 27 2025-02-19   Andrew                  andrew_ghazi@hms.harvard.edu
# 28 2025-02-26  Andreas               andreas_werdich@hms.harvard.edu
#
#        group  holiday                  comment
# 0    ai-data    False                     None
# 1   comp-bio    False                     None
# 2    ai-data    False                     None
# 3   comp-bio    False  No meeting, party time.
# 4   comp-bio    False                     None
# 5    ai-data    False                     None
# 6   comp-bio    False                     None
# 7    ai-data    False                     None
# 8   comp-bio    False                     None
# 9   comp-bio    False                     None
# 10   ai-data    False                     None
# 11  comp-bio    False                     None
# 12   ai-data    False                     None
# 13  comp-bio    False                     None
# 14   ai-data    False                     None
# 15  comp-bio    False                     None
# 16   ai-data    False                     None
# 17  comp-bio    False                     None
# 18  comp-bio    False                     None
# 19   ai-data     True            Christmas Day
# 20  comp-bio     True           New Year's Day
# 21   ai-data    False                     None
# 22  comp-bio    False                     None
# 23   ai-data    False                     None
# 24  comp-bio    False                     None
# 25   ai-data    False                     None
# 26  comp-bio    False                     None
# 27  comp-bio    False                     None
# 28   ai-data    False                     None

# %% [markdown]
# ### Function to swap meeting dates ###

# %%
def in_list(lst, elements):
    """ Return true only if all elements are in the list lst """
    check_lst = [True if el in lst else False for el in elements]
    return all(check_lst)

def swap_elements(lst, el1, el2):
    """ Swap el1 and el2 in list lst if both el1 and el2 are in lst """
    new_lst = lst.copy()
    if in_list(lst=lst, elements=[el1, el2]):
        idx1, idx2 = lst.index(el1), lst.index(el2)
        new_lst[idx1], new_lst[idx2] = new_lst[idx2], new_lst[idx1]
    else:
        raise ValueError(f'Input list "lst" does not contain "{el1}" or "{el2}".')
    return new_lst

# %%
lst = ['a', 'b', 'c', 'd', 'e', 'f']
el_lst = ['b', 'c']
print(in_list(lst=lst, elements=el_lst))
print(lst)
print(swap_elements(lst=lst, el1='b', el2='x'))
# Out:
# True
# ['a', 'b', 'c', 'd', 'e', 'f']
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[70], line 5
#       3 print(in_list(lst=lst, elements=el_lst))
#       4 print(lst)
# ----> 5 print(swap_elements(lst=lst, el1='b', el2='x'))
#
# Cell In[66], line 13, in swap_elements(lst, el1, el2)
#      11     new_lst[idx1], new_lst[idx2] = new_lst[idx2], new_lst[idx1]
#      12 else:
# ---> 13     raise ValueError(f'Input list "lst" does not contain "{el1}" or "{el2}".')
#      14 return new_lst
#
# ValueError: Input list "lst" does not contain "b" or "x".

# %%
'x' in lst
# Out:
# False

# %%
# Create a new meeting schedule
start_date = '2024-08-14'
end_date = '2025-01-31'

cal_df = create_timeboard(start_date=start_date, 
                          end_date=end_date, 
                          name_list=presenters,
                          start_name='anthony')

display(cal_df)
# Out:
# /home/andreas/gitrepos/pyutils/.venv/lib/python3.10/site-packages/timeboard/when.py:37: FutureWarning: 'S' is deprecated and will be removed in a future version, please use 's' instead.
#   start_times = pi.to_timestamp(how='start', freq='S')
#          date     name                                         email  \
# 0  2024-08-14  Anthony  anthony-alexander_christidis@hms.harvard.edu
# 1  2024-08-21   Gerald               gerald_kiwanuka@hms.harvard.edu
# 2  2024-08-28     Grey                   grey_kuling@hms.harvard.edu
# 3  2024-09-04      Sam              samantha_pullman@hms.harvard.edu
# 4  2024-09-11     Tram                   tram_nguyen@hms.harvard.edu
# 5  2024-09-18    Sreya                sreya_banerjee@hms.harvard.edu
# 6  2024-09-25   Tyrone                    tyrone_lee@hms.harvard.edu
# 7  2024-10-02   Andrew                  andrew_ghazi@hms.harvard.edu
# 8  2024-10-09  Andreas               andreas_werdich@hms.harvard.edu
# 9  2024-10-16  Anthony  anthony-alexander_christidis@hms.harvard.edu
# 10 2024-10-23   Gerald               gerald_kiwanuka@hms.harvard.edu
# 11 2024-10-30     Grey                   grey_kuling@hms.harvard.edu
# 12 2024-11-06      Sam              samantha_pullman@hms.harvard.edu
# 13 2024-11-13     Tram                   tram_nguyen@hms.harvard.edu
# 14 2024-11-20    Sreya                sreya_banerjee@hms.harvard.edu
# 15 2024-11-27   Tyrone                    tyrone_lee@hms.harvard.edu
# 16 2024-12-04   Andrew                  andrew_ghazi@hms.harvard.edu
# 17 2024-12-11  Andreas               andreas_werdich@hms.harvard.edu
# 18 2024-12-18  Anthony  anthony-alexander_christidis@hms.harvard.edu
# 19 2024-12-25   Gerald               gerald_kiwanuka@hms.harvard.edu
# 20 2025-01-01     Grey                   grey_kuling@hms.harvard.edu
# 21 2025-01-08      Sam              samantha_pullman@hms.harvard.edu
# 22 2025-01-15     Tram                   tram_nguyen@hms.harvard.edu
# 23 2025-01-22    Sreya                sreya_banerjee@hms.harvard.edu
# 24 2025-01-29   Tyrone                    tyrone_lee@hms.harvard.edu
#
#        group  holiday         comment
# 0   comp-bio    False            None
# 1    ai-data    False            None
# 2   comp-bio    False            None
# 3    ai-data    False            None
# 4   comp-bio    False            None
# 5    ai-data    False            None
# 6   comp-bio    False            None
# 7   comp-bio    False            None
# 8    ai-data    False            None
# 9   comp-bio    False            None
# 10   ai-data    False            None
# 11  comp-bio    False            None
# 12   ai-data    False            None
# 13  comp-bio    False            None
# 14   ai-data    False            None
# 15  comp-bio    False            None
# 16  comp-bio    False            None
# 17   ai-data    False            None
# 18  comp-bio    False            None
# 19   ai-data     True   Christmas Day
# 20  comp-bio     True  New Year's Day
# 21   ai-data    False            None
# 22  comp-bio    False            None
# 23   ai-data    False            None
# 24  comp-bio    False            None

# %%
# Swap two dates
dt1 = '2024-08-28' # Grey
dt2 = '2024-09-18' # Sreya

cal_df_before = cal_df.copy()
cal_df_after = cal_df.copy()

date_list = cal_df.get(date_col).values
cal_df_after.index = date_list

# %%
display(cal_df_after.head(7))
# Out:
#                  date     name                                         email  \
# 2024-08-14 2024-08-14  Anthony  anthony-alexander_christidis@hms.harvard.edu
# 2024-08-21 2024-08-21   Gerald               gerald_kiwanuka@hms.harvard.edu
# 2024-08-28 2024-08-28     Grey                   grey_kuling@hms.harvard.edu
# 2024-09-04 2024-09-04      Sam              samantha_pullman@hms.harvard.edu
# 2024-09-11 2024-09-11     Tram                   tram_nguyen@hms.harvard.edu
# 2024-09-18 2024-09-18    Sreya                sreya_banerjee@hms.harvard.edu
# 2024-09-25 2024-09-25   Tyrone                    tyrone_lee@hms.harvard.edu
#
#                group  holiday comment
# 2024-08-14  comp-bio    False    None
# 2024-08-21   ai-data    False    None
# 2024-08-28  comp-bio    False    None
# 2024-09-04   ai-data    False    None
# 2024-09-11  comp-bio    False    None
# 2024-09-18   ai-data    False    None
# 2024-09-25  comp-bio    False    None

# %%
display(cal_new)
# Out:
#                  date    name                             email    group  \
# date
# 2024-08-28 2024-08-28  Gerald   gerald_kiwanuka@hms.harvard.edu  ai-data
# 2024-09-18 2024-09-18     Sam  samantha_pullman@hms.harvard.edu  ai-data
#
#             holiday comment
# date
# 2024-08-28    False    None
# 2024-09-18    False    None
